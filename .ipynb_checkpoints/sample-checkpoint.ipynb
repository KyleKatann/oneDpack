# %%
from oneDpack import*
import random

for i in packing(100,[random.randint(1,100) for i in range(100)]):
    print(sum(i))
    print(i)
# Out:
# Using license file C:\Users\kyle\gurobi.lic
# Academic license - for non-commercial use only
# 100
# [4, 96]
# 100
# [1, 36, 63]
# 100
# [47, 53]
# 100
# [42, 58]
# 100
# [21, 79]
# 100
# [100]
# 100
# [100]
# 100
# [100]
# 99
# [5, 6, 23, 65]
# 99
# [49, 50]
# 99
# [4, 8, 87]
# 99
# [22, 77]
# 99
# [22, 77]
# 99
# [30, 69]
# 99
# [45, 54]
# 99
# [42, 57]
# 98
# [10, 10, 78]
# 98
# [10, 33, 55]
# 98
# [14, 16, 68]
# 98
# [14, 16, 68]
# 98
# [39, 59]
# 98
# [39, 59]
# 98
# [35, 63]
# 97
# [19, 78]
# 97
# [97]
# 97
# [39, 58]
# 97
# [43, 54]
# 96
# [28, 68]
# 94
# [94]
# 94
# [47, 47]
# 94
# [25, 69]
# 94
# [28, 66]
# 94
# [21, 73]
# 93
# [31, 62]
# 93
# [93]
# 93
# [93]
# 93
# [93]
# 92
# [20, 72]
# 91
# [2, 89]
# 91
# [21, 70]
# 90
# [2, 88]
# 90
# [9, 10, 71]
# 89
# [13, 76]
# 87
# [87]
# 87
# [87]
# 87
# [3, 84]
# 86
# [86]
# 84
# [84]
# 83
# [83]
# 83
# [83]
# 82
# [14, 68]
# 80
# [9, 71]
# 76
# [76]
